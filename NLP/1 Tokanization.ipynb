# %%
corpus = """My name is Amaan Behlim.
I am a Final Year Student. 
Studying in CSE (AI/ML) course.
I've Been Going through Some Machine Learning courses"""
print(corpus)
# Out:
# My name is Amaan Behlim. I am a Final Year Student. Studying in CSE (AI/ML) course.I've Been Going through Some Machine Learning courses

# %%
from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(corpus)
sentence
# Out:
# ['My name is Amaan Behlim.',
#  'I am a Final Year Student.',
#  "Studying in CSE (AI/ML) course.I've Been Going through Some Machine Learning courses"]

# %%
for sentence in sentence:
    print(sentence)
# Out:
# My name is Amaan Behlim.
# I am a Final Year Student.
# Studying in CSE (AI/ML) course.I've Been Going through Some Machine Learning courses

# %%
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['My',
#  'name',
#  'is',
#  'Amaan',
#  'Behlim',
#  '.',
#  'I',
#  'am',
#  'a',
#  'Final',
#  'Year',
#  'Student',
#  '.',
#  'Studying',
#  'in',
#  'CSE',
#  '(',
#  'AI/ML',
#  ')',
#  'course.I',
#  "'ve",
#  'Been',
#  'Going',
#  'through',
#  'Some',
#  'Machine',
#  'Learning',
#  'courses']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['My',
#  'name',
#  'is',
#  'Amaan',
#  'Behlim.',
#  'I',
#  'am',
#  'a',
#  'Final',
#  'Year',
#  'Student.',
#  'Studying',
#  'in',
#  'CSE',
#  '(',
#  'AI/ML',
#  ')',
#  'course.I',
#  "'ve",
#  'Been',
#  'Going',
#  'through',
#  'Some',
#  'Machine',
#  'Learning',
#  'courses']
